# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="A6yWeYWehJT3H7b3UJGY")
project = rf.workspace("segundoparcial").project("examen2")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/Examen2-1
# Out:
# /content/Examen2-1

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !yolo task=detect mode=train model=yolov8l-seg.pt data= /content/Examen2-1/data.yaml epochs=5 imgsz=640
# Out:
# ...
# 100% 88.1M/88.1M [00:00<00:00, 271MB/s]
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/Examen2-1/runs/segment/train/confusion_matrix.png', width=800)

# %%
Image(filename='/content/Examen2-1/runs/segment/train/val_batch1_labels.jpg', width=600)

# %%
# !yolo task=detect mode=val model=/content/Examen2-1/runs/segment/train/weights/best.pt data=data.yaml
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=segment' model. Ignoring 'task=detect' and updating to 'task=segment' to match model.
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45914201 parameters, 0 gradients, 220.1 GFLOPs
# val: Scanning /content/Examen2-1/valid/labels.cache... 575 images, 1 backgrounds, 0 corrupt: 100% 575/575 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 36/36 [00:25<00:00,  1.43it/s]
#                    all        575       1082      0.875       0.89      0.908      0.787      0.874      0.886      0.901      0.765
#                  focos        575        209       0.87      0.933      0.965      0.836      0.868      0.928      0.962      0.843
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# Ruta de la carpeta en Colab
carpeta_en_colab = '/content/Examen2-1/runs'

# Ruta de destino en Google Drive
ruta_en_drive = '/content/drive/MyDrive/yolo_8'

# Copiar la carpeta y su contenido a Google Drive
shutil.copytree(carpeta_en_colab, ruta_en_drive + '01')
# Out:
# '/content/drive/MyDrive/yolo_801'

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
Image(filename='/content/drive/MyDrive/yolo_801/segment/train/val_batch1_labels.jpg', width=600)

# %%
import cv2
from IPython.display import Image
from ultralytics import YOLO
img_name='71gNZzvbISL._UX250_'
img =cv2.imread(f"/content/{img_name}.jpg")
# Mostrar la imagen en una ventana
Image(filename=f"/content/{img_name}.jpg", width=800)

# %%
model= YOLO("/content/drive/MyDrive/yolo_801/segment/train/weights/best.pt")
pred= model.predict(img)[0]
pred= pred.plot()
cv2.imwrite(f"{img_name}.jpg", pred)
# Out:
# 0: 640x480 2 focoss, 114.6ms
# Speed: 2.2ms preprocess, 114.6ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 480)
# True

# %%
Image(filename=f"/content/{img_name}.jpg", width=600)

# %%
import cv2
from IPython.display import Image
from ultralytics import YOLO
img_name='QQQ511SOMcXJnL._UX250_'
img =cv2.imread(f"/content/{img_name}.jpg")
# Mostrar la imagen en una ventana
Image(filename=f"/content/{img_name}.jpg", width=800)

# %%
model= YOLO("/content/drive/MyDrive/yolo_801/segment/train/weights/best.pt")
pred= model.predict(img)[0]
pred= pred.plot()
cv2.imwrite(f"{img_name}.jpg", pred)
# Out:
# 0: 640x480 1 focos, 61.8ms
# Speed: 2.4ms preprocess, 61.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
# True

# %%
Image(filename=f"/content/{img_name}.jpg", width=600)

# %%
import cv2
from IPython.display import Image
from ultralytics import YOLO
img_name='Pimages (1)'
img =cv2.imread(f"/content/{img_name}.jpg")
# Mostrar la imagen en una ventana
Image(filename=f"/content/{img_name}.jpg", width=800)

# %%
model= YOLO("/content/drive/MyDrive/yolo_801/segment/train/weights/best.pt")
pred= model.predict(img)[0]
pred= pred.plot()
cv2.imwrite(f"{img_name}.jpg", pred)
# Out:
# 0: 448x640 1 interruptores, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 2.9ms postprocess per image at shape (1, 3, 448, 640)
# True

# %%
Image(filename=f"/content/{img_name}.jpg", width=600)

# %%
import cv2
from IPython.display import Image
from ultralytics import YOLO
img_name='cerca-de-un-monton-de-accesorios-de-madera-tendido-horizontalmente-e1bjn1'
img =cv2.imread(f"/content/{img_name}.jpg")
# Mostrar la imagen en una ventana
Image(filename=f"/content/{img_name}.jpg", width=800)

# %%
model= YOLO("/content/drive/MyDrive/yolo_801/segment/train/weights/best.pt")
pred= model.predict(img)[0]
pred= pred.plot()
cv2.imwrite(f"{img_name}.jpg", pred)
# Out:
# 0: 544x640 3 puntales de maderas, 264.6ms
# Speed: 4.0ms preprocess, 264.6ms inference, 4.3ms postprocess per image at shape (1, 3, 544, 640)
# True

# %%
Image(filename=f"/content/{img_name}.jpg", width=600)

# %%
import cv2
from IPython.display import Image
from ultralytics import YOLO
img_name='encofrado-de-madera-soportado-por-puntales-para-la-colada-de-losa-de-hormigón'
img =cv2.imread(f"/content/{img_name}.jpg")
# Mostrar la imagen en una ventana
Image(filename=f"/content/{img_name}.jpg", width=800)

# %%
model= YOLO("/content/drive/MyDrive/yolo_801/segment/train/weights/best.pt")
pred= model.predict(img)[0]
pred= pred.plot()
cv2.imwrite(f"{img_name}.jpg", pred)
# Out:
# 0: 480x640 6 puntales de maderas, 56.2ms
# Speed: 2.9ms preprocess, 56.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# True

# %%
Image(filename=f"/content/{img_name}.jpg", width=600)
